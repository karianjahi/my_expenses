# %%
negate = [3.5, 42.1, 24.1, 41.5, 94.1]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(len(negate)), negate, color="black")
plt.grid()

# %%
'Siku moja tu baada ya wana/mirengo ya Tangatanga na Kieleweke kuzomeana jana kwenye vikao viwili tofauti. Hii leo rais Uhuru Kenyatta, na naibu wake William Ruto wamefanya kikao siku kutwa ikulu yake. Kati ya masuala mengi wa'
# Out:
# 'Siku moja tu baada ya wana/mirengo ya Tangatanga na Kieleweke kuzomeana jana kwenye vikao viwili tofauti. Hii leo rais Uhuru Kenyatta, na naibu wake William Ruto wamefanya kikao siku kutwa ikulu yake. Kati ya masuala mengi wa'
